# %% [markdown]
# ## Data structures and algorithm exams
#
# Create a database of your choice using a linear data structure and Python.

# %% [markdown]
# ## Python-based implementation of the Cyberspace database using a linear data structure (lists and dictionaries) and SQLite.
#
# ### The solution includes:
#
# - ✔ Database Schema (Students, Courses, Lecturers)
#
# - ✔ Primary Keys (PKs) and Foreign Keys (FKs)
#
# - ✔ Data Population (50 students per department, 10 lecturers, 20 courses)
#
# - ✔ Time Complexity Analysis

# %% [markdown]
# # Step 1: Database Schema and Relationships
# ### Tables & Relationships:
#
# - Students (PK: Student_ID, FK: Course_ID)
# - Each student belongs to a department and can enroll in multiple courses.
# - Courses (PK: Course_ID)
# - Shared among departments. Students from any department can take courses.
# - Lecturers (PK: Lecturer_ID, FK: Department)
# - Each lecturer belongs to a department and teaches multiple courses.
# - Enrollment (PK: Student_ID, Course_ID)
# - Many-to-many relationship: One student can enroll in multiple courses.
#
#
# # Step 2: Python Implementation
#
# - ✅ Create SQLite database (cyberspacedb.db).
# - ✅ Use lists and dictionaries to store student, lecturer, and course data.
# - ✅ Populate the database with randomized data.
# - ✅ Perform queries (e.g., finding all courses for a student).
# - ✅ Analyze time complexity for key operations.

# %% [markdown]
# # 1. Import Required Libraries

# %%
import sqlite3
import random
import time

# %% [markdown]
# # 2. Create Database and Tables

# %%
# Connect to SQLite
conn = sqlite3.connect("cyberspaceDB.db")
cursor = conn.cursor()

# %%
# Create Tables
cursor.executescript("""
    CREATE TABLE IF NOT EXISTS Department (
        Dept_ID INTEGER PRIMARY KEY AUTOINCREMENT,
        Name TEXT UNIQUE NOT NULL
    );

    CREATE TABLE IF NOT EXISTS Students (
        Student_ID INTEGER PRIMARY KEY AUTOINCREMENT,
        Name TEXT NOT NULL,
        Dept_ID INTEGER NOT NULL,
        FOREIGN KEY (Dept_ID) REFERENCES Department(Dept_ID)
    );

    CREATE TABLE IF NOT EXISTS Courses (
        Course_ID INTEGER PRIMARY KEY AUTOINCREMENT,
        Course_Name TEXT UNIQUE NOT NULL,
        Credits INTEGER NOT NULL
    );

    CREATE TABLE IF NOT EXISTS Lecturers (
        Lecturer_ID INTEGER PRIMARY KEY AUTOINCREMENT,
        Name TEXT NOT NULL,
        Dept_ID INTEGER NOT NULL,
        FOREIGN KEY (Dept_ID) REFERENCES Department(Dept_ID)
    );

    CREATE TABLE IF NOT EXISTS Enrollment (
        Student_ID INTEGER NOT NULL,
        Course_ID INTEGER NOT NULL,
        PRIMARY KEY (Student_ID, Course_ID),
        FOREIGN KEY (Student_ID) REFERENCES Students(Student_ID),
        FOREIGN KEY (Course_ID) REFERENCES Courses(Course_ID)
    );
""")
conn.commit()

# %% [markdown]
# ## Explanation
# - Department Table stores department names (Data Science, Computer Science, Cyber Security).
# - Students Table links students to their department (Dept_ID).
# - Courses Table has course details (name, credits).
# - Lecturers Table links lecturers to their department.
# - Enrollment Table handles many-to-many relationships between students and courses.

# %% [markdown]
# # 3. Insert Data (Departments, Students, Courses, Lecturers)

# %%
# Departments
departments = ["Data Science", "Computer Science", "Cyber Security"]
cursor.executemany("INSERT OR IGNORE INTO Department (Name) VALUES (?)", [(d,) for d in departments])
conn.commit()

# Fetch Department IDs
cursor.execute("SELECT * FROM Department")
dept_dict = {name: dept_id for dept_id, name in cursor.fetchall()}

# %%
# Fetch data from Department table
cursor.execute("SELECT * FROM Department")
departments = cursor.fetchall()

# Display the department data
print("\nDepartment Table Data:")
print("-" * 40)
print(f"{'Dept_ID':<10}{'Name':<20}")
print("-" * 40)
for dept in departments:
    print(f"{dept[0]:<10}{dept[1]:<20}")
# Out:
# Department Table Data:
# ----------------------------------------
# Dept_ID   Name
# ----------------------------------------
# 1         Data Science
# 2         Computer Science
# 3         Cyber Security

# %%
# Generate Sample Names
def generate_name():
    first_names = ["Alice", "Bob", "Charlie", "David", "Emma", "Frank", "Grace", "Hannah"]
    last_names = ["Johnson", "Smith", "Williams", "Brown", "Jones", "Garcia"]
    return f"{random.choice(first_names)} {random.choice(last_names)}"

# Insert Students (50 per department)
for dept, dept_id in dept_dict.items():
    students = [(generate_name(), dept_id) for _ in range(50)]
    cursor.executemany("INSERT INTO Students (Name, Dept_ID) VALUES (?, ?)", students)

# %%
# Fetch data from Students table
cursor.execute("SELECT * FROM Students")
students = cursor.fetchall()

# Display the student data
print("\nStudents Table Data:")
print("-" * 50)
print(f"{'Student_ID':<12}{'Name':<25}{'Dept_ID':<10}")
print("-" * 50)
for student in students:
    print(f"{student[0]:<12}{student[1]:<25}{student[2]:<10}")
# Out:
# Students Table Data:
# --------------------------------------------------
# Student_ID  Name                     Dept_ID
# --------------------------------------------------
# 1           Charlie Smith            1
# 2           Bob Smith                1
# 3           Alice Smith              1
# 4           Alice Johnson            1
# 5           Charlie Johnson          1
# 6           Charlie Jones            1
# 7           Hannah Brown             1
# 8           Grace Jones              1
# 9           Hannah Brown             1
# 10          Charlie Williams         1
# 11          Emma Williams            1
# 12          Charlie Johnson          1
# 13          Charlie Johnson          1
# 14          Emma Jones               1
# 15          Hannah Brown             1
# 16          David Garcia             1
# 17          Emma Williams            1
# 18          Hannah Garcia            1
# 19          Frank Johnson            1
# 20          Emma Williams            1
# 21          Charlie Smith            1
# 22          Frank Johnson            1
# 23          Bob Smith                1
# 24          Grace Brown              1
# 25          Bob Garcia               1
# 26          David Garcia             1
# 27          Charlie Brown            1
# 28          Hannah Smith             1
# 29          Alice Smith              1
# 30          Emma Johnson             1
# 31          David Smith              1
# 32          Grace Brown              1
# 33          Emma Jones               1
# 34          Bob Johnson              1
# 35          Bob Garcia               1
# 36          Alice Jones              1
# 37          Bob Brown                1
# 38          Emma Williams            1
# 39          Hannah Williams          1
# 40          Bob Williams             1
# 41          Charlie Brown            1
# 42          Bob Brown                1
# 43          David Williams           1
# 44          Hannah Brown             1
# 45          Alice Brown              1
# 46          Emma Smith               1
# 47          Frank Johnson            1
# 48          David Williams           1
# 49          Frank Smith              1
# 50          Emma Smith               1
# 51          Bob Johnson              2
# 52          Grace Garcia             2
# 53          Charlie Smith            2
# 54          Grace Johnson            2
# 55          David Brown              2
# 56          Grace Johnson            2
# 57          Bob Jones                2
# 58          Bob Brown                2
# 59          Grace Garcia             2
# 60          Alice Jones              2
# 61          Frank Williams           2
# 62          Grace Brown              2
# 63          Hannah Brown             2
# 64          Hannah Garcia            2
# 65          Hannah Jones             2
# 66          Charlie Williams         2
# 67          Hannah Jones             2
# 68          David Jones              2
# 69          Alice Jones              2
# 70          Bob Johnson              2
# 71          Charlie Brown            2
# 72          Alice Garcia             2
# 73          Emma Garcia              2
# 74          Emma Garcia              2
# 75          Frank Brown              2
# 76          David Smith              2
# 77          Bob Jones                2
# 78          Charlie Johnson          2
# 79          Bob Brown                2
# 80          Charlie Johnson          2
# 81          Frank Brown              2
# 82          David Smith              2
# 83          Hannah Johnson           2
# 84          Frank Williams           2
# 85          Grace Brown              2
# 86          David Smith              2
# 87          Charlie Jones            2
# 88          Grace Garcia             2
# 89          Alice Williams           2
# 90          Bob Garcia               2
# 91          Charlie Garcia           2
# 92          Charlie Brown            2
# 93          Charlie Garcia           2
# 94          Grace Johnson            2
# 95          Grace Williams           2
# 96          David Brown              2
# 97          David Brown              2
# 98          Bob Brown                2
# 99          Grace Garcia             2
# 100         Bob Jones                2
# 101         Bob Jones                3
# 102         Alice Johnson            3
# 103         Grace Smith              3
# 104         Charlie Williams         3
# 105         Hannah Jones             3
# 106         Hannah Garcia            3
# 107         Bob Garcia               3
# 108         Bob Brown                3
# 109         Grace Williams           3
# 110         Hannah Garcia            3
# 111         Bob Brown                3
# 112         David Johnson            3
# 113         Bob Smith                3
# 114         David Garcia             3
# 115         Alice Garcia             3
# 116         Emma Johnson             3
# 117         Frank Smith              3
# 118         Charlie Johnson          3
# 119         Bob Jones                3
# 120         Grace Smith              3
# 121         Hannah Garcia            3
# 122         Alice Brown              3
# 123         Hannah Jones             3
# 124         Emma Brown               3
# 125         David Williams           3
# 126         Emma Williams            3
# 127         Hannah Jones             3
# 128         Alice Jones              3
# 129         Grace Johnson            3
# 130         Charlie Johnson          3
# 131         Frank Johnson            3
# 132         Emma Smith               3
# 133         Bob Williams             3
# 134         Alice Johnson            3
# 135         Bob Brown                3
# 136         Emma Jones               3
# 137         Frank Johnson            3
# 138         Alice Johnson            3
# 139         Charlie Williams         3
# 140         Hannah Williams          3
# 141         Grace Brown              3
# 142         Frank Brown              3
# 143         Grace Garcia             3
# 144         Charlie Brown            3
# 145         Frank Brown              3
# 146         Emma Johnson             3
# 147         David Johnson            3
# 148         Hannah Jones             3
# 149         Emma Garcia              3
# 150         Hannah Williams          3

# %%
# Fetch students with department names using INNER JOIN
cursor.execute("""
    SELECT Students.Student_ID, Students.Name, Department.Name 
    FROM Students
    INNER JOIN Department ON Students.Dept_ID = Department.Dept_ID
""")
students = cursor.fetchall()

# Display student data with department names
print("\nStudents Table Data (With Department Names):")
print("-" * 60)
print(f"{'Student_ID':<12}{'Name':<25}{'Department':<20}")
print("-" * 60)
for student in students:
    print(f"{student[0]:<12}{student[1]:<25}{student[2]:<20}")
# Out:
# Students Table Data (With Department Names):
# ------------------------------------------------------------
# Student_ID  Name                     Department
# ------------------------------------------------------------
# 1           Charlie Smith            Data Science
# 2           Bob Smith                Data Science
# 3           Alice Smith              Data Science
# 4           Alice Johnson            Data Science
# 5           Charlie Johnson          Data Science
# 6           Charlie Jones            Data Science
# 7           Hannah Brown             Data Science
# 8           Grace Jones              Data Science
# 9           Hannah Brown             Data Science
# 10          Charlie Williams         Data Science
# 11          Emma Williams            Data Science
# 12          Charlie Johnson          Data Science
# 13          Charlie Johnson          Data Science
# 14          Emma Jones               Data Science
# 15          Hannah Brown             Data Science
# 16          David Garcia             Data Science
# 17          Emma Williams            Data Science
# 18          Hannah Garcia            Data Science
# 19          Frank Johnson            Data Science
# 20          Emma Williams            Data Science
# 21          Charlie Smith            Data Science
# 22          Frank Johnson            Data Science
# 23          Bob Smith                Data Science
# 24          Grace Brown              Data Science
# 25          Bob Garcia               Data Science
# 26          David Garcia             Data Science
# 27          Charlie Brown            Data Science
# 28          Hannah Smith             Data Science
# 29          Alice Smith              Data Science
# 30          Emma Johnson             Data Science
# 31          David Smith              Data Science
# 32          Grace Brown              Data Science
# 33          Emma Jones               Data Science
# 34          Bob Johnson              Data Science
# 35          Bob Garcia               Data Science
# 36          Alice Jones              Data Science
# 37          Bob Brown                Data Science
# 38          Emma Williams            Data Science
# 39          Hannah Williams          Data Science
# 40          Bob Williams             Data Science
# 41          Charlie Brown            Data Science
# 42          Bob Brown                Data Science
# 43          David Williams           Data Science
# 44          Hannah Brown             Data Science
# 45          Alice Brown              Data Science
# 46          Emma Smith               Data Science
# 47          Frank Johnson            Data Science
# 48          David Williams           Data Science
# 49          Frank Smith              Data Science
# 50          Emma Smith               Data Science
# 51          Bob Johnson              Computer Science
# 52          Grace Garcia             Computer Science
# 53          Charlie Smith            Computer Science
# 54          Grace Johnson            Computer Science
# 55          David Brown              Computer Science
# 56          Grace Johnson            Computer Science
# 57          Bob Jones                Computer Science
# 58          Bob Brown                Computer Science
# 59          Grace Garcia             Computer Science
# 60          Alice Jones              Computer Science
# 61          Frank Williams           Computer Science
# 62          Grace Brown              Computer Science
# 63          Hannah Brown             Computer Science
# 64          Hannah Garcia            Computer Science
# 65          Hannah Jones             Computer Science
# 66          Charlie Williams         Computer Science
# 67          Hannah Jones             Computer Science
# 68          David Jones              Computer Science
# 69          Alice Jones              Computer Science
# 70          Bob Johnson              Computer Science
# 71          Charlie Brown            Computer Science
# 72          Alice Garcia             Computer Science
# 73          Emma Garcia              Computer Science
# 74          Emma Garcia              Computer Science
# 75          Frank Brown              Computer Science
# 76          David Smith              Computer Science
# 77          Bob Jones                Computer Science
# 78          Charlie Johnson          Computer Science
# 79          Bob Brown                Computer Science
# 80          Charlie Johnson          Computer Science
# 81          Frank Brown              Computer Science
# 82          David Smith              Computer Science
# 83          Hannah Johnson           Computer Science
# 84          Frank Williams           Computer Science
# 85          Grace Brown              Computer Science
# 86          David Smith              Computer Science
# 87          Charlie Jones            Computer Science
# 88          Grace Garcia             Computer Science
# 89          Alice Williams           Computer Science
# 90          Bob Garcia               Computer Science
# 91          Charlie Garcia           Computer Science
# 92          Charlie Brown            Computer Science
# 93          Charlie Garcia           Computer Science
# 94          Grace Johnson            Computer Science
# 95          Grace Williams           Computer Science
# 96          David Brown              Computer Science
# 97          David Brown              Computer Science
# 98          Bob Brown                Computer Science
# 99          Grace Garcia             Computer Science
# 100         Bob Jones                Computer Science
# 101         Bob Jones                Cyber Security
# 102         Alice Johnson            Cyber Security
# 103         Grace Smith              Cyber Security
# 104         Charlie Williams         Cyber Security
# 105         Hannah Jones             Cyber Security
# 106         Hannah Garcia            Cyber Security
# 107         Bob Garcia               Cyber Security
# 108         Bob Brown                Cyber Security
# 109         Grace Williams           Cyber Security
# 110         Hannah Garcia            Cyber Security
# 111         Bob Brown                Cyber Security
# 112         David Johnson            Cyber Security
# 113         Bob Smith                Cyber Security
# 114         David Garcia             Cyber Security
# 115         Alice Garcia             Cyber Security
# 116         Emma Johnson             Cyber Security
# 117         Frank Smith              Cyber Security
# 118         Charlie Johnson          Cyber Security
# 119         Bob Jones                Cyber Security
# 120         Grace Smith              Cyber Security
# 121         Hannah Garcia            Cyber Security
# 122         Alice Brown              Cyber Security
# 123         Hannah Jones             Cyber Security
# 124         Emma Brown               Cyber Security
# 125         David Williams           Cyber Security
# 126         Emma Williams            Cyber Security
# 127         Hannah Jones             Cyber Security
# 128         Alice Jones              Cyber Security
# 129         Grace Johnson            Cyber Security
# 130         Charlie Johnson          Cyber Security
# 131         Frank Johnson            Cyber Security
# 132         Emma Smith               Cyber Security
# 133         Bob Williams             Cyber Security
# 134         Alice Johnson            Cyber Security
# 135         Bob Brown                Cyber Security
# 136         Emma Jones               Cyber Security
# 137         Frank Johnson            Cyber Security
# 138         Alice Johnson            Cyber Security
# 139         Charlie Williams         Cyber Security
# 140         Hannah Williams          Cyber Security
# 141         Grace Brown              Cyber Security
# 142         Frank Brown              Cyber Security
# 143         Grace Garcia             Cyber Security
# 144         Charlie Brown            Cyber Security
# 145         Frank Brown              Cyber Security
# 146         Emma Johnson             Cyber Security
# 147         David Johnson            Cyber Security
# 148         Hannah Jones             Cyber Security
# 149         Emma Garcia              Cyber Security
# 150         Hannah Williams          Cyber Security

# %%
# Query to select only Data Science students
cursor.execute("""
    SELECT Students.Student_ID, Students.Name, Department.Name AS Department
    FROM Students
    INNER JOIN Department ON Students.Dept_ID = Department.Dept_ID
    WHERE Department.Name = 'Data Science'
""")
students = cursor.fetchall()

# Display the results
print("\nData Science Students:")
print("-" * 50)
print(f"{'Student_ID':<12}{'Name':<25}{'Department':<15}")
print("-" * 50)
for student in students:
    print(f"{student[0]:<12}{student[1]:<25}{student[2]:<15}")
# Out:
# Data Science Students:
# --------------------------------------------------
# Student_ID  Name                     Department
# --------------------------------------------------
# 1           Charlie Smith            Data Science
# 2           Bob Smith                Data Science
# 3           Alice Smith              Data Science
# 4           Alice Johnson            Data Science
# 5           Charlie Johnson          Data Science
# 6           Charlie Jones            Data Science
# 7           Hannah Brown             Data Science
# 8           Grace Jones              Data Science
# 9           Hannah Brown             Data Science
# 10          Charlie Williams         Data Science
# 11          Emma Williams            Data Science
# 12          Charlie Johnson          Data Science
# 13          Charlie Johnson          Data Science
# 14          Emma Jones               Data Science
# 15          Hannah Brown             Data Science
# 16          David Garcia             Data Science
# 17          Emma Williams            Data Science
# 18          Hannah Garcia            Data Science
# 19          Frank Johnson            Data Science
# 20          Emma Williams            Data Science
# 21          Charlie Smith            Data Science
# 22          Frank Johnson            Data Science
# 23          Bob Smith                Data Science
# 24          Grace Brown              Data Science
# 25          Bob Garcia               Data Science
# 26          David Garcia             Data Science
# 27          Charlie Brown            Data Science
# 28          Hannah Smith             Data Science
# 29          Alice Smith              Data Science
# 30          Emma Johnson             Data Science
# 31          David Smith              Data Science
# 32          Grace Brown              Data Science
# 33          Emma Jones               Data Science
# 34          Bob Johnson              Data Science
# 35          Bob Garcia               Data Science
# 36          Alice Jones              Data Science
# 37          Bob Brown                Data Science
# 38          Emma Williams            Data Science
# 39          Hannah Williams          Data Science
# 40          Bob Williams             Data Science
# 41          Charlie Brown            Data Science
# 42          Bob Brown                Data Science
# 43          David Williams           Data Science
# 44          Hannah Brown             Data Science
# 45          Alice Brown              Data Science
# 46          Emma Smith               Data Science
# 47          Frank Johnson            Data Science
# 48          David Williams           Data Science
# 49          Frank Smith              Data Science
# 50          Emma Smith               Data Science

# %%
# Insert Courses (20 courses)
courses = [
    ("Data Science Fundamentals", 3), ("Machine Learning", 4), ("Cybersecurity Basics", 3),
    ("Database Management", 4), ("Programming in Python", 3), ("Network Security", 4),
    ("Software Engineering", 3), ("Operating Systems", 3), ("AI & Deep Learning", 4),
    ("Cryptography", 4), ("Data Visualization", 3), ("Web Development", 3),
    ("Ethical Hacking", 4), ("Computer Vision", 3), ("Cloud Computing", 4),
    ("Data Mining", 3), ("Software Testing", 3), ("Blockchain Security", 4),
    ("Digital Forensics", 4), ("Advanced Algorithms", 4)
]
cursor.executemany("INSERT INTO Courses (Course_Name, Credits) VALUES (?, ?)", courses)

# Insert Lecturers (10 lecturers)
lecturers = [(generate_name(), random.choice(list(dept_dict.values()))) for _ in range(10)]
cursor.executemany("INSERT INTO Lecturers (Name, Dept_ID) VALUES (?, ?)", lecturers)
conn.commit()

# %%
# Fetch data from Courses table
cursor.execute("SELECT * FROM Courses")
courses = cursor.fetchall()

# Display the course data
print("\nCourses Table Data:")
print("-" * 50)
print(f"{'Course_ID':<12}{'Course_Name':<30}{'Credits':<8}")
print("-" * 50)
for course in courses:
    print(f"{course[0]:<12}{course[1]:<30}{course[2]:<8}")
# Out:
# Courses Table Data:
# --------------------------------------------------
# Course_ID   Course_Name                   Credits
# --------------------------------------------------
# 1           Data Science Fundamentals     3
# 2           Machine Learning              4
# 3           Cybersecurity Basics          3
# 4           Database Management           4
# 5           Programming in Python         3
# 6           Network Security              4
# 7           Software Engineering          3
# 8           Operating Systems             3
# 9           AI & Deep Learning            4
# 10          Cryptography                  4
# 11          Data Visualization            3
# 12          Web Development               3
# 13          Ethical Hacking               4
# 14          Computer Vision               3
# 15          Cloud Computing               4
# 16          Data Mining                   3
# 17          Software Testing              3
# 18          Blockchain Security           4
# 19          Digital Forensics             4
# 20          Advanced Algorithms           4

# %%
# Fetch data from Lecturers table
cursor.execute("SELECT * FROM Lecturers")
lecturers = cursor.fetchall()

# Display the lecturer data
print("\nLecturers Table Data:")
print("-" * 60)
print(f"{'Lecturer_ID':<12}{'Name':<25}{'Department_ID':<15}")
print("-" * 60)
for lecturer in lecturers:
    print(f"{lecturer[0]:<12}{lecturer[1]:<25}{lecturer[2]:<15}")
# Out:
# Lecturers Table Data:
# ------------------------------------------------------------
# Lecturer_ID Name                     Department_ID
# ------------------------------------------------------------
# 1           Grace Williams           3
# 2           Grace Garcia             1
# 3           Bob Brown                2
# 4           Frank Garcia             2
# 5           Charlie Williams         2
# 6           Bob Garcia               1
# 7           David Williams           1
# 8           Emma Johnson             2
# 9           Grace Johnson            3
# 10          Grace Smith              2

# %% [markdown]
# # Explanation
# - Generates random names for students and lecturers.
# - Assigns 50 students per department.
# - Adds 20 courses, shared across departments.
# - Assigns 10 lecturers to random departments.

# %% [markdown]
# # 4. Enroll Students in Random Courses

# %%
cursor.execute("SELECT Student_ID FROM Students")
student_ids = [row[0] for row in cursor.fetchall()]

cursor.execute("SELECT Course_ID FROM Courses")
course_ids = [row[0] for row in cursor.fetchall()]

# Assign each student 3-5 random courses
enrollments = []
for student_id in student_ids:
    chosen_courses = random.sample(course_ids, random.randint(3, 5))
    for course_id in chosen_courses:
        enrollments.append((student_id, course_id))

cursor.executemany("INSERT INTO Enrollment (Student_ID, Course_ID) VALUES (?, ?)", enrollments)
conn.commit()

# %%
# Fetch data from Enrollment table
cursor.execute("SELECT * FROM Enrollment")
enrollments = cursor.fetchall()

# Display the enrollment data
print("\nEnrollment Table Data:")
print("-" * 50)
print(f"{'Student_ID':<12}{'Course_ID':<12}")
print("-" * 50)
for enrollment in enrollments:
    print(f"{enrollment[0]:<12}{enrollment[1]:<12}")
# Out:
# Enrollment Table Data:
# --------------------------------------------------
# Student_ID  Course_ID
# --------------------------------------------------
# 1           13
# 1           4
# 1           18
# 1           14
# 1           9
# 2           11
# 2           15
# 2           5
# 2           12
# 3           15
# 3           18
# 3           6
# 3           17
# 4           2
# 4           20
# 4           6
# 5           7
# 5           20
# 5           14
# 5           5
# 5           15
# 6           20
# 6           10
# 6           7
# 6           13
# 7           15
# 7           12
# 7           6
# 7           13
# 8           19
# 8           5
# 8           15
# 9           10
# 9           3
# 9           13
# 9           19
# 10          17
# 10          5
# 10          1
# 10          8
# 10          6
# 11          16
# 11          19
# 11          11
# 11          17
# 12          3
# 12          18
# 12          7
# 13          14
# 13          9
# 13          18
# 14          8
# 14          12
# 14          15
# 15          14
# 15          15
# 15          18
# 16          18
# 16          20
# 16          6
# 17          4
# 17          7
# 17          20
# 17          14
# 18          9
# 18          14
# 18          17
# 19          14
# 19          5
# 19          15
# 19          8
# 19          7
# 20          13
# 20          19
# 20          3
# 20          10
# 20          7
# 21          16
# 21          6
# 21          8
# 21          7
# 22          7
# 22          16
# 22          15
# 22          4
# 22          14
# 23          6
# 23          10
# 23          7
# 24          5
# 24          4
# 24          15
# 25          19
# 25          13
# 25          15
# 25          5
# 25          16
# 26          2
# 26          12
# 26          4
# 27          2
# 27          14
# 27          10
# 28          6
# 28          5
# 28          8
# 29          11
# 29          19
# 29          5
# 30          10
# 30          14
# 30          9
# 30          7
# 30          11
# 31          10
# 31          14
# 31          6
# 31          11
# 31          19
# 32          13
# 32          17
# 32          7
# 33          12
# 33          20
# 33          6
# 34          12
# 34          5
# 34          16
# 34          17
# 34          9
# 35          14
# 35          8
# 35          18
# 36          4
# 36          19
# 36          8
# 37          8
# 37          5
# 37          15
# 37          2
# 37          3
# 38          15
# 38          5
# 38          12
# 38          20
# 39          12
# 39          3
# 39          2
# 40          19
# 40          14
# 40          3
# 41          2
# 41          16
# 41          13
# 41          19
# 41          5
# 42          13
# 42          11
# 42          2
# 43          3
# 43          1
# 43          7
# 44          6
# 44          3
# 44          17
# 45          18
# 45          13
# 45          11
# 46          17
# 46          2
# 46          18
# 47          14
# 47          12
# 47          2
# 47          16
# 48          12
# 48          2
# 48          17
# 49          17
# 49          18
# 49          5
# 49          11
# 49          2
# 50          3
# 50          11
# 50          18
# 50          7
# 51          3
# 51          14
# 51          18
# 52          17
# 52          16
# 52          10
# 52          1
# 53          20
# 53          16
# 53          9
# 53          15
# 54          8
# 54          13
# 54          14
# 54          17
# 55          13
# 55          7
# 55          18
# 56          2
# 56          18
# 56          3
# 57          15
# 57          9
# 57          19
# 57          2
# 58          11
# 58          4
# 58          15
# 58          3
# 58          1
# 59          20
# 59          12
# 59          8
# 60          4
# 60          14
# 60          12
# 60          16
# 61          20
# 61          7
# 61          17
# 61          19
# 61          16
# 62          14
# 62          1
# 62          8
# 62          17
# 63          3
# 63          7
# 63          12
# 63          16
# 64          2
# 64          14
# 64          15
# 64          16
# 65          8
# 65          10
# 65          19
# 65          14
# 66          15
# 66          18
# 66          10
# 67          20
# 67          17
# 67          6
# 67          4
# 68          5
# 68          3
# 68          19
# 68          18
# 68          9
# 69          20
# 69          8
# 69          15
# 69          2
# 69          5
# 70          15
# 70          12
# 70          10
# 71          9
# 71          5
# 71          19
# 71          8
# 72          2
# 72          1
# 72          20
# 73          19
# 73          14
# 73          1
# 73          5
# 74          11
# 74          7
# 74          18
# 74          3
# 74          15
# 75          9
# 75          5
# 75          3
# 75          10
# 76          6
# 76          1
# 76          10
# 76          7
# 77          20
# 77          2
# 77          16
# 78          5
# 78          1
# 78          12
# 79          14
# 79          17
# 79          2
# 79          16
# 79          20
# 80          17
# 80          8
# 80          13
# 80          6
# 80          15
# 81          13
# 81          19
# 81          18
# 81          10
# 82          2
# 82          18
# 82          13
# 82          17
# 83          7
# 83          6
# 83          12
# 83          2
# 84          16
# 84          10
# 84          20
# 84          15
# 85          8
# 85          7
# 85          5
# 85          18
# 86          12
# 86          15
# 86          9
# 87          15
# 87          17
# 87          3
# 87          1
# 88          1
# 88          5
# 88          9
# 88          19
# 88          7
# 89          7
# 89          17
# 89          2
# 90          10
# 90          3
# 90          15
# 90          8
# 90          14
# 91          17
# 91          14
# 91          3
# 91          13
# 91          10
# 92          3
# 92          15
# 92          17
# 92          5
# 92          12
# 93          5
# 93          11
# 93          14
# 93          9
# 94          18
# 94          8
# 94          16
# 95          20
# 95          9
# 95          11
# 96          14
# 96          3
# 96          2
# 97          14
# 97          20
# 97          7
# 97          12
# 97          15
# 98          11
# 98          14
# 98          16
# 98          6
# 98          9
# 99          7
# 99          16
# 99          4
# 99          2
# 100         19
# 100         2
# 100         11
# 100         17
# 100         4
# 101         4
# 101         7
# 101         9
# 101         20
# 101         11
# 102         13
# 102         6
# 102         20
# 102         10
# 103         3
# 103         4
# 103         16
# 103         20
# 103         18
# 104         1
# 104         14
# 104         15
# 105         1
# 105         2
# 105         11
# 105         7
# 105         6
# 106         14
# 106         12
# 106         5
# 106         15
# 106         2
# 107         11
# 107         13
# 107         17
# 108         6
# 108         3
# 108         15
# 108         19
# 108         1
# 109         9
# 109         14
# 109         19
# 109         6
# 109         8
# 110         4
# 110         6
# 110         15
# 111         1
# 111         19
# 111         7
# 112         20
# 112         16
# 112         4
# 113         3
# 113         4
# 113         13
# 114         19
# 114         6
# 114         7
# 114         3
# 114         8
# 115         5
# 115         19
# 115         13
# 116         4
# 116         18
# 116         13
# 116         17
# 117         16
# 117         15
# 117         19
# 117         17
# 117         1
# 118         19
# 118         12
# 118         20
# 118         11
# 118         14
# 119         17
# 119         3
# 119         19
# 119         16
# 120         10
# 120         4
# 120         2
# 120         8
# 121         6
# 121         19
# 121         2
# 121         8
# 122         17
# 122         11
# 122         19
# 122         15
# 123         8
# 123         6
# 123         17
# 124         10
# 124         9
# 124         12
# 125         11
# 125         6
# 125         18
# 126         6
# 126         10
# 126         9
# 126         8
# 126         17
# 127         5
# 127         19
# 127         6
# 128         6
# 128         12
# 128         4
# 129         12
# 129         4
# 129         14
# 129         8
# 129         2
# 130         12
# 130         4
# 130         3
# 130         5
# 131         6
# 131         19
# 131         16
# 131         10
# 131         5
# 132         14
# 132         10
# 132         16
# 132         8
# 133         18
# 133         15
# 133         14
# 133         10
# 133         1
# 134         16
# 134         3
# 134         6
# 134         14
# 135         7
# 135         14
# 135         6
# 136         2
# 136         12
# 136         18
# 136         14
# 136         11
# 137         17
# 137         18
# 137         12
# 137         14
# 137         11
# 138         1
# 138         7
# 138         4
# 138         5
# 139         12
# 139         13
# 139         8
# 139         4
# 140         15
# 140         1
# 140         10
# 140         17
# 141         6
# 141         8
# 141         17
# 141         13
# 142         7
# 142         13
# 142         20
# 142         5
# 143         3
# 143         18
# 143         10
# 143         13
# 144         3
# 144         9
# 144         12
# 144         16
# 145         6
# 145         5
# 145         20
# 145         16
# 146         11
# 146         16
# 146         12
# 146         20
# 146         14
# 147         16
# 147         15
# 147         9
# 147         6
# 148         12
# 148         15
# 148         14
# 148         16
# 148         9
# 149         14
# 149         19
# 149         1
# 150         14
# 150         11
# 150         6

# %%
# Fetch enrollment data with student names and course names
cursor.execute("""
    SELECT Students.Student_ID, Students.Name, Courses.Course_ID, Courses.Course_Name
    FROM Enrollment
    INNER JOIN Students ON Enrollment.Student_ID = Students.Student_ID
    INNER JOIN Courses ON Enrollment.Course_ID = Courses.Course_ID
""")
enrollments = cursor.fetchall()

# Display the enrollment data
print("\nEnrollment Table Data (With Student & Course Names):")
print("-" * 80)
print(f"{'Student_ID':<12}{'Student_Name':<25}{'Course_ID':<12}{'Course_Name':<30}")
print("-" * 80)
for enrollment in enrollments:
    print(f"{enrollment[0]:<12}{enrollment[1]:<25}{enrollment[2]:<12}{enrollment[3]:<30}")
# Out:
# Enrollment Table Data (With Student & Course Names):
# --------------------------------------------------------------------------------
# Student_ID  Student_Name             Course_ID   Course_Name
# --------------------------------------------------------------------------------
# 1           Charlie Smith            13          Ethical Hacking
# 1           Charlie Smith            4           Database Management
# 1           Charlie Smith            18          Blockchain Security
# 1           Charlie Smith            14          Computer Vision
# 1           Charlie Smith            9           AI & Deep Learning
# 2           Bob Smith                11          Data Visualization
# 2           Bob Smith                15          Cloud Computing
# 2           Bob Smith                5           Programming in Python
# 2           Bob Smith                12          Web Development
# 3           Alice Smith              15          Cloud Computing
# 3           Alice Smith              18          Blockchain Security
# 3           Alice Smith              6           Network Security
# 3           Alice Smith              17          Software Testing
# 4           Alice Johnson            2           Machine Learning
# 4           Alice Johnson            20          Advanced Algorithms
# 4           Alice Johnson            6           Network Security
# 5           Charlie Johnson          7           Software Engineering
# 5           Charlie Johnson          20          Advanced Algorithms
# 5           Charlie Johnson          14          Computer Vision
# 5           Charlie Johnson          5           Programming in Python
# 5           Charlie Johnson          15          Cloud Computing
# 6           Charlie Jones            20          Advanced Algorithms
# 6           Charlie Jones            10          Cryptography
# 6           Charlie Jones            7           Software Engineering
# 6           Charlie Jones            13          Ethical Hacking
# 7           Hannah Brown             15          Cloud Computing
# 7           Hannah Brown             12          Web Development
# 7           Hannah Brown             6           Network Security
# 7           Hannah Brown             13          Ethical Hacking
# 8           Grace Jones              19          Digital Forensics
# 8           Grace Jones              5           Programming in Python
# 8           Grace Jones              15          Cloud Computing
# 9           Hannah Brown             10          Cryptography
# 9           Hannah Brown             3           Cybersecurity Basics
# 9           Hannah Brown             13          Ethical Hacking
# 9           Hannah Brown             19          Digital Forensics
# 10          Charlie Williams         17          Software Testing
# 10          Charlie Williams         5           Programming in Python
# 10          Charlie Williams         1           Data Science Fundamentals
# 10          Charlie Williams         8           Operating Systems
# 10          Charlie Williams         6           Network Security
# 11          Emma Williams            16          Data Mining
# 11          Emma Williams            19          Digital Forensics
# 11          Emma Williams            11          Data Visualization
# 11          Emma Williams            17          Software Testing
# 12          Charlie Johnson          3           Cybersecurity Basics
# 12          Charlie Johnson          18          Blockchain Security
# 12          Charlie Johnson          7           Software Engineering
# 13          Charlie Johnson          14          Computer Vision
# 13          Charlie Johnson          9           AI & Deep Learning
# 13          Charlie Johnson          18          Blockchain Security
# 14          Emma Jones               8           Operating Systems
# 14          Emma Jones               12          Web Development
# 14          Emma Jones               15          Cloud Computing
# 15          Hannah Brown             14          Computer Vision
# 15          Hannah Brown             15          Cloud Computing
# 15          Hannah Brown             18          Blockchain Security
# 16          David Garcia             18          Blockchain Security
# 16          David Garcia             20          Advanced Algorithms
# 16          David Garcia             6           Network Security
# 17          Emma Williams            4           Database Management
# 17          Emma Williams            7           Software Engineering
# 17          Emma Williams            20          Advanced Algorithms
# 17          Emma Williams            14          Computer Vision
# 18          Hannah Garcia            9           AI & Deep Learning
# 18          Hannah Garcia            14          Computer Vision
# 18          Hannah Garcia            17          Software Testing
# 19          Frank Johnson            14          Computer Vision
# 19          Frank Johnson            5           Programming in Python
# 19          Frank Johnson            15          Cloud Computing
# 19          Frank Johnson            8           Operating Systems
# 19          Frank Johnson            7           Software Engineering
# 20          Emma Williams            13          Ethical Hacking
# 20          Emma Williams            19          Digital Forensics
# 20          Emma Williams            3           Cybersecurity Basics
# 20          Emma Williams            10          Cryptography
# 20          Emma Williams            7           Software Engineering
# 21          Charlie Smith            16          Data Mining
# 21          Charlie Smith            6           Network Security
# 21          Charlie Smith            8           Operating Systems
# 21          Charlie Smith            7           Software Engineering
# 22          Frank Johnson            7           Software Engineering
# 22          Frank Johnson            16          Data Mining
# 22          Frank Johnson            15          Cloud Computing
# 22          Frank Johnson            4           Database Management
# 22          Frank Johnson            14          Computer Vision
# 23          Bob Smith                6           Network Security
# 23          Bob Smith                10          Cryptography
# 23          Bob Smith                7           Software Engineering
# 24          Grace Brown              5           Programming in Python
# 24          Grace Brown              4           Database Management
# 24          Grace Brown              15          Cloud Computing
# 25          Bob Garcia               19          Digital Forensics
# 25          Bob Garcia               13          Ethical Hacking
# 25          Bob Garcia               15          Cloud Computing
# 25          Bob Garcia               5           Programming in Python
# 25          Bob Garcia               16          Data Mining
# 26          David Garcia             2           Machine Learning
# 26          David Garcia             12          Web Development
# 26          David Garcia             4           Database Management
# 27          Charlie Brown            2           Machine Learning
# 27          Charlie Brown            14          Computer Vision
# 27          Charlie Brown            10          Cryptography
# 28          Hannah Smith             6           Network Security
# 28          Hannah Smith             5           Programming in Python
# 28          Hannah Smith             8           Operating Systems
# 29          Alice Smith              11          Data Visualization
# 29          Alice Smith              19          Digital Forensics
# 29          Alice Smith              5           Programming in Python
# 30          Emma Johnson             10          Cryptography
# 30          Emma Johnson             14          Computer Vision
# 30          Emma Johnson             9           AI & Deep Learning
# 30          Emma Johnson             7           Software Engineering
# 30          Emma Johnson             11          Data Visualization
# 31          David Smith              10          Cryptography
# 31          David Smith              14          Computer Vision
# 31          David Smith              6           Network Security
# 31          David Smith              11          Data Visualization
# 31          David Smith              19          Digital Forensics
# 32          Grace Brown              13          Ethical Hacking
# 32          Grace Brown              17          Software Testing
# 32          Grace Brown              7           Software Engineering
# 33          Emma Jones               12          Web Development
# 33          Emma Jones               20          Advanced Algorithms
# 33          Emma Jones               6           Network Security
# 34          Bob Johnson              12          Web Development
# 34          Bob Johnson              5           Programming in Python
# 34          Bob Johnson              16          Data Mining
# 34          Bob Johnson              17          Software Testing
# 34          Bob Johnson              9           AI & Deep Learning
# 35          Bob Garcia               14          Computer Vision
# 35          Bob Garcia               8           Operating Systems
# 35          Bob Garcia               18          Blockchain Security
# 36          Alice Jones              4           Database Management
# 36          Alice Jones              19          Digital Forensics
# 36          Alice Jones              8           Operating Systems
# 37          Bob Brown                8           Operating Systems
# 37          Bob Brown                5           Programming in Python
# 37          Bob Brown                15          Cloud Computing
# 37          Bob Brown                2           Machine Learning
# 37          Bob Brown                3           Cybersecurity Basics
# 38          Emma Williams            15          Cloud Computing
# 38          Emma Williams            5           Programming in Python
# 38          Emma Williams            12          Web Development
# 38          Emma Williams            20          Advanced Algorithms
# 39          Hannah Williams          12          Web Development
# 39          Hannah Williams          3           Cybersecurity Basics
# 39          Hannah Williams          2           Machine Learning
# 40          Bob Williams             19          Digital Forensics
# 40          Bob Williams             14          Computer Vision
# 40          Bob Williams             3           Cybersecurity Basics
# 41          Charlie Brown            2           Machine Learning
# 41          Charlie Brown            16          Data Mining
# 41          Charlie Brown            13          Ethical Hacking
# 41          Charlie Brown            19          Digital Forensics
# 41          Charlie Brown            5           Programming in Python
# 42          Bob Brown                13          Ethical Hacking
# 42          Bob Brown                11          Data Visualization
# 42          Bob Brown                2           Machine Learning
# 43          David Williams           3           Cybersecurity Basics
# 43          David Williams           1           Data Science Fundamentals
# 43          David Williams           7           Software Engineering
# 44          Hannah Brown             6           Network Security
# 44          Hannah Brown             3           Cybersecurity Basics
# 44          Hannah Brown             17          Software Testing
# 45          Alice Brown              18          Blockchain Security
# 45          Alice Brown              13          Ethical Hacking
# 45          Alice Brown              11          Data Visualization
# 46          Emma Smith               17          Software Testing
# 46          Emma Smith               2           Machine Learning
# 46          Emma Smith               18          Blockchain Security
# 47          Frank Johnson            14          Computer Vision
# 47          Frank Johnson            12          Web Development
# 47          Frank Johnson            2           Machine Learning
# 47          Frank Johnson            16          Data Mining
# 48          David Williams           12          Web Development
# 48          David Williams           2           Machine Learning
# 48          David Williams           17          Software Testing
# 49          Frank Smith              17          Software Testing
# 49          Frank Smith              18          Blockchain Security
# 49          Frank Smith              5           Programming in Python
# 49          Frank Smith              11          Data Visualization
# 49          Frank Smith              2           Machine Learning
# 50          Emma Smith               3           Cybersecurity Basics
# 50          Emma Smith               11          Data Visualization
# 50          Emma Smith               18          Blockchain Security
# 50          Emma Smith               7           Software Engineering
# 51          Bob Johnson              3           Cybersecurity Basics
# 51          Bob Johnson              14          Computer Vision
# 51          Bob Johnson              18          Blockchain Security
# 52          Grace Garcia             17          Software Testing
# 52          Grace Garcia             16          Data Mining
# 52          Grace Garcia             10          Cryptography
# 52          Grace Garcia             1           Data Science Fundamentals
# 53          Charlie Smith            20          Advanced Algorithms
# 53          Charlie Smith            16          Data Mining
# 53          Charlie Smith            9           AI & Deep Learning
# 53          Charlie Smith            15          Cloud Computing
# 54          Grace Johnson            8           Operating Systems
# 54          Grace Johnson            13          Ethical Hacking
# 54          Grace Johnson            14          Computer Vision
# 54          Grace Johnson            17          Software Testing
# 55          David Brown              13          Ethical Hacking
# 55          David Brown              7           Software Engineering
# 55          David Brown              18          Blockchain Security
# 56          Grace Johnson            2           Machine Learning
# 56          Grace Johnson            18          Blockchain Security
# 56          Grace Johnson            3           Cybersecurity Basics
# 57          Bob Jones                15          Cloud Computing
# 57          Bob Jones                9           AI & Deep Learning
# 57          Bob Jones                19          Digital Forensics
# 57          Bob Jones                2           Machine Learning
# 58          Bob Brown                11          Data Visualization
# 58          Bob Brown                4           Database Management
# 58          Bob Brown                15          Cloud Computing
# 58          Bob Brown                3           Cybersecurity Basics
# 58          Bob Brown                1           Data Science Fundamentals
# 59          Grace Garcia             20          Advanced Algorithms
# 59          Grace Garcia             12          Web Development
# 59          Grace Garcia             8           Operating Systems
# 60          Alice Jones              4           Database Management
# 60          Alice Jones              14          Computer Vision
# 60          Alice Jones              12          Web Development
# 60          Alice Jones              16          Data Mining
# 61          Frank Williams           20          Advanced Algorithms
# 61          Frank Williams           7           Software Engineering
# 61          Frank Williams           17          Software Testing
# 61          Frank Williams           19          Digital Forensics
# 61          Frank Williams           16          Data Mining
# 62          Grace Brown              14          Computer Vision
# 62          Grace Brown              1           Data Science Fundamentals
# 62          Grace Brown              8           Operating Systems
# 62          Grace Brown              17          Software Testing
# 63          Hannah Brown             3           Cybersecurity Basics
# 63          Hannah Brown             7           Software Engineering
# 63          Hannah Brown             12          Web Development
# 63          Hannah Brown             16          Data Mining
# 64          Hannah Garcia            2           Machine Learning
# 64          Hannah Garcia            14          Computer Vision
# 64          Hannah Garcia            15          Cloud Computing
# 64          Hannah Garcia            16          Data Mining
# 65          Hannah Jones             8           Operating Systems
# 65          Hannah Jones             10          Cryptography
# 65          Hannah Jones             19          Digital Forensics
# 65          Hannah Jones             14          Computer Vision
# 66          Charlie Williams         15          Cloud Computing
# 66          Charlie Williams         18          Blockchain Security
# 66          Charlie Williams         10          Cryptography
# 67          Hannah Jones             20          Advanced Algorithms
# 67          Hannah Jones             17          Software Testing
# 67          Hannah Jones             6           Network Security
# 67          Hannah Jones             4           Database Management
# 68          David Jones              5           Programming in Python
# 68          David Jones              3           Cybersecurity Basics
# 68          David Jones              19          Digital Forensics
# 68          David Jones              18          Blockchain Security
# 68          David Jones              9           AI & Deep Learning
# 69          Alice Jones              20          Advanced Algorithms
# 69          Alice Jones              8           Operating Systems
# 69          Alice Jones              15          Cloud Computing
# 69          Alice Jones              2           Machine Learning
# 69          Alice Jones              5           Programming in Python
# 70          Bob Johnson              15          Cloud Computing
# 70          Bob Johnson              12          Web Development
# 70          Bob Johnson              10          Cryptography
# 71          Charlie Brown            9           AI & Deep Learning
# 71          Charlie Brown            5           Programming in Python
# 71          Charlie Brown            19          Digital Forensics
# 71          Charlie Brown            8           Operating Systems
# 72          Alice Garcia             2           Machine Learning
# 72          Alice Garcia             1           Data Science Fundamentals
# 72          Alice Garcia             20          Advanced Algorithms
# 73          Emma Garcia              19          Digital Forensics
# 73          Emma Garcia              14          Computer Vision
# 73          Emma Garcia              1           Data Science Fundamentals
# 73          Emma Garcia              5           Programming in Python
# 74          Emma Garcia              11          Data Visualization
# 74          Emma Garcia              7           Software Engineering
# 74          Emma Garcia              18          Blockchain Security
# 74          Emma Garcia              3           Cybersecurity Basics
# 74          Emma Garcia              15          Cloud Computing
# 75          Frank Brown              9           AI & Deep Learning
# 75          Frank Brown              5           Programming in Python
# 75          Frank Brown              3           Cybersecurity Basics
# 75          Frank Brown              10          Cryptography
# 76          David Smith              6           Network Security
# 76          David Smith              1           Data Science Fundamentals
# 76          David Smith              10          Cryptography
# 76          David Smith              7           Software Engineering
# 77          Bob Jones                20          Advanced Algorithms
# 77          Bob Jones                2           Machine Learning
# 77          Bob Jones                16          Data Mining
# 78          Charlie Johnson          5           Programming in Python
# 78          Charlie Johnson          1           Data Science Fundamentals
# 78          Charlie Johnson          12          Web Development
# 79          Bob Brown                14          Computer Vision
# 79          Bob Brown                17          Software Testing
# 79          Bob Brown                2           Machine Learning
# 79          Bob Brown                16          Data Mining
# 79          Bob Brown                20          Advanced Algorithms
# 80          Charlie Johnson          17          Software Testing
# 80          Charlie Johnson          8           Operating Systems
# 80          Charlie Johnson          13          Ethical Hacking
# 80          Charlie Johnson          6           Network Security
# 80          Charlie Johnson          15          Cloud Computing
# 81          Frank Brown              13          Ethical Hacking
# 81          Frank Brown              19          Digital Forensics
# 81          Frank Brown              18          Blockchain Security
# 81          Frank Brown              10          Cryptography
# 82          David Smith              2           Machine Learning
# 82          David Smith              18          Blockchain Security
# 82          David Smith              13          Ethical Hacking
# 82          David Smith              17          Software Testing
# 83          Hannah Johnson           7           Software Engineering
# 83          Hannah Johnson           6           Network Security
# 83          Hannah Johnson           12          Web Development
# 83          Hannah Johnson           2           Machine Learning
# 84          Frank Williams           16          Data Mining
# 84          Frank Williams           10          Cryptography
# 84          Frank Williams           20          Advanced Algorithms
# 84          Frank Williams           15          Cloud Computing
# 85          Grace Brown              8           Operating Systems
# 85          Grace Brown              7           Software Engineering
# 85          Grace Brown              5           Programming in Python
# 85          Grace Brown              18          Blockchain Security
# 86          David Smith              12          Web Development
# 86          David Smith              15          Cloud Computing
# 86          David Smith              9           AI & Deep Learning
# 87          Charlie Jones            15          Cloud Computing
# 87          Charlie Jones            17          Software Testing
# 87          Charlie Jones            3           Cybersecurity Basics
# 87          Charlie Jones            1           Data Science Fundamentals
# 88          Grace Garcia             1           Data Science Fundamentals
# 88          Grace Garcia             5           Programming in Python
# 88          Grace Garcia             9           AI & Deep Learning
# 88          Grace Garcia             19          Digital Forensics
# 88          Grace Garcia             7           Software Engineering
# 89          Alice Williams           7           Software Engineering
# 89          Alice Williams           17          Software Testing
# 89          Alice Williams           2           Machine Learning
# 90          Bob Garcia               10          Cryptography
# 90          Bob Garcia               3           Cybersecurity Basics
# 90          Bob Garcia               15          Cloud Computing
# 90          Bob Garcia               8           Operating Systems
# 90          Bob Garcia               14          Computer Vision
# 91          Charlie Garcia           17          Software Testing
# 91          Charlie Garcia           14          Computer Vision
# 91          Charlie Garcia           3           Cybersecurity Basics
# 91          Charlie Garcia           13          Ethical Hacking
# 91          Charlie Garcia           10          Cryptography
# 92          Charlie Brown            3           Cybersecurity Basics
# 92          Charlie Brown            15          Cloud Computing
# 92          Charlie Brown            17          Software Testing
# 92          Charlie Brown            5           Programming in Python
# 92          Charlie Brown            12          Web Development
# 93          Charlie Garcia           5           Programming in Python
# 93          Charlie Garcia           11          Data Visualization
# 93          Charlie Garcia           14          Computer Vision
# 93          Charlie Garcia           9           AI & Deep Learning
# 94          Grace Johnson            18          Blockchain Security
# 94          Grace Johnson            8           Operating Systems
# 94          Grace Johnson            16          Data Mining
# 95          Grace Williams           20          Advanced Algorithms
# 95          Grace Williams           9           AI & Deep Learning
# 95          Grace Williams           11          Data Visualization
# 96          David Brown              14          Computer Vision
# 96          David Brown              3           Cybersecurity Basics
# 96          David Brown              2           Machine Learning
# 97          David Brown              14          Computer Vision
# 97          David Brown              20          Advanced Algorithms
# 97          David Brown              7           Software Engineering
# 97          David Brown              12          Web Development
# 97          David Brown              15          Cloud Computing
# 98          Bob Brown                11          Data Visualization
# 98          Bob Brown                14          Computer Vision
# 98          Bob Brown                16          Data Mining
# 98          Bob Brown                6           Network Security
# 98          Bob Brown                9           AI & Deep Learning
# 99          Grace Garcia             7           Software Engineering
# 99          Grace Garcia             16          Data Mining
# 99          Grace Garcia             4           Database Management
# 99          Grace Garcia             2           Machine Learning
# 100         Bob Jones                19          Digital Forensics
# 100         Bob Jones                2           Machine Learning
# 100         Bob Jones                11          Data Visualization
# 100         Bob Jones                17          Software Testing
# 100         Bob Jones                4           Database Management
# 101         Bob Jones                4           Database Management
# 101         Bob Jones                7           Software Engineering
# 101         Bob Jones                9           AI & Deep Learning
# 101         Bob Jones                20          Advanced Algorithms
# 101         Bob Jones                11          Data Visualization
# 102         Alice Johnson            13          Ethical Hacking
# 102         Alice Johnson            6           Network Security
# 102         Alice Johnson            20          Advanced Algorithms
# 102         Alice Johnson            10          Cryptography
# 103         Grace Smith              3           Cybersecurity Basics
# 103         Grace Smith              4           Database Management
# 103         Grace Smith              16          Data Mining
# 103         Grace Smith              20          Advanced Algorithms
# 103         Grace Smith              18          Blockchain Security
# 104         Charlie Williams         1           Data Science Fundamentals
# 104         Charlie Williams         14          Computer Vision
# 104         Charlie Williams         15          Cloud Computing
# 105         Hannah Jones             1           Data Science Fundamentals
# 105         Hannah Jones             2           Machine Learning
# 105         Hannah Jones             11          Data Visualization
# 105         Hannah Jones             7           Software Engineering
# 105         Hannah Jones             6           Network Security
# 106         Hannah Garcia            14          Computer Vision
# 106         Hannah Garcia            12          Web Development
# 106         Hannah Garcia            5           Programming in Python
# 106         Hannah Garcia            15          Cloud Computing
# 106         Hannah Garcia            2           Machine Learning
# 107         Bob Garcia               11          Data Visualization
# 107         Bob Garcia               13          Ethical Hacking
# 107         Bob Garcia               17          Software Testing
# 108         Bob Brown                6           Network Security
# 108         Bob Brown                3           Cybersecurity Basics
# 108         Bob Brown                15          Cloud Computing
# 108         Bob Brown                19          Digital Forensics
# 108         Bob Brown                1           Data Science Fundamentals
# 109         Grace Williams           9           AI & Deep Learning
# 109         Grace Williams           14          Computer Vision
# 109         Grace Williams           19          Digital Forensics
# 109         Grace Williams           6           Network Security
# 109         Grace Williams           8           Operating Systems
# 110         Hannah Garcia            4           Database Management
# 110         Hannah Garcia            6           Network Security
# 110         Hannah Garcia            15          Cloud Computing
# 111         Bob Brown                1           Data Science Fundamentals
# 111         Bob Brown                19          Digital Forensics
# 111         Bob Brown                7           Software Engineering
# 112         David Johnson            20          Advanced Algorithms
# 112         David Johnson            16          Data Mining
# 112         David Johnson            4           Database Management
# 113         Bob Smith                3           Cybersecurity Basics
# 113         Bob Smith                4           Database Management
# 113         Bob Smith                13          Ethical Hacking
# 114         David Garcia             19          Digital Forensics
# 114         David Garcia             6           Network Security
# 114         David Garcia             7           Software Engineering
# 114         David Garcia             3           Cybersecurity Basics
# 114         David Garcia             8           Operating Systems
# 115         Alice Garcia             5           Programming in Python
# 115         Alice Garcia             19          Digital Forensics
# 115         Alice Garcia             13          Ethical Hacking
# 116         Emma Johnson             4           Database Management
# 116         Emma Johnson             18          Blockchain Security
# 116         Emma Johnson             13          Ethical Hacking
# 116         Emma Johnson             17          Software Testing
# 117         Frank Smith              16          Data Mining
# 117         Frank Smith              15          Cloud Computing
# 117         Frank Smith              19          Digital Forensics
# 117         Frank Smith              17          Software Testing
# 117         Frank Smith              1           Data Science Fundamentals
# 118         Charlie Johnson          19          Digital Forensics
# 118         Charlie Johnson          12          Web Development
# 118         Charlie Johnson          20          Advanced Algorithms
# 118         Charlie Johnson          11          Data Visualization
# 118         Charlie Johnson          14          Computer Vision
# 119         Bob Jones                17          Software Testing
# 119         Bob Jones                3           Cybersecurity Basics
# 119         Bob Jones                19          Digital Forensics
# 119         Bob Jones                16          Data Mining
# 120         Grace Smith              10          Cryptography
# 120         Grace Smith              4           Database Management
# 120         Grace Smith              2           Machine Learning
# 120         Grace Smith              8           Operating Systems
# 121         Hannah Garcia            6           Network Security
# 121         Hannah Garcia            19          Digital Forensics
# 121         Hannah Garcia            2           Machine Learning
# 121         Hannah Garcia            8           Operating Systems
# 122         Alice Brown              17          Software Testing
# 122         Alice Brown              11          Data Visualization
# 122         Alice Brown              19          Digital Forensics
# 122         Alice Brown              15          Cloud Computing
# 123         Hannah Jones             8           Operating Systems
# 123         Hannah Jones             6           Network Security
# 123         Hannah Jones             17          Software Testing
# 124         Emma Brown               10          Cryptography
# 124         Emma Brown               9           AI & Deep Learning
# 124         Emma Brown               12          Web Development
# 125         David Williams           11          Data Visualization
# 125         David Williams           6           Network Security
# 125         David Williams           18          Blockchain Security
# 126         Emma Williams            6           Network Security
# 126         Emma Williams            10          Cryptography
# 126         Emma Williams            9           AI & Deep Learning
# 126         Emma Williams            8           Operating Systems
# 126         Emma Williams            17          Software Testing
# 127         Hannah Jones             5           Programming in Python
# 127         Hannah Jones             19          Digital Forensics
# 127         Hannah Jones             6           Network Security
# 128         Alice Jones              6           Network Security
# 128         Alice Jones              12          Web Development
# 128         Alice Jones              4           Database Management
# 129         Grace Johnson            12          Web Development
# 129         Grace Johnson            4           Database Management
# 129         Grace Johnson            14          Computer Vision
# 129         Grace Johnson            8           Operating Systems
# 129         Grace Johnson            2           Machine Learning
# 130         Charlie Johnson          12          Web Development
# 130         Charlie Johnson          4           Database Management
# 130         Charlie Johnson          3           Cybersecurity Basics
# 130         Charlie Johnson          5           Programming in Python
# 131         Frank Johnson            6           Network Security
# 131         Frank Johnson            19          Digital Forensics
# 131         Frank Johnson            16          Data Mining
# 131         Frank Johnson            10          Cryptography
# 131         Frank Johnson            5           Programming in Python
# 132         Emma Smith               14          Computer Vision
# 132         Emma Smith               10          Cryptography
# 132         Emma Smith               16          Data Mining
# 132         Emma Smith               8           Operating Systems
# 133         Bob Williams             18          Blockchain Security
# 133         Bob Williams             15          Cloud Computing
# 133         Bob Williams             14          Computer Vision
# 133         Bob Williams             10          Cryptography
# 133         Bob Williams             1           Data Science Fundamentals
# 134         Alice Johnson            16          Data Mining
# 134         Alice Johnson            3           Cybersecurity Basics
# 134         Alice Johnson            6           Network Security
# 134         Alice Johnson            14          Computer Vision
# 135         Bob Brown                7           Software Engineering
# 135         Bob Brown                14          Computer Vision
# 135         Bob Brown                6           Network Security
# 136         Emma Jones               2           Machine Learning
# 136         Emma Jones               12          Web Development
# 136         Emma Jones               18          Blockchain Security
# 136         Emma Jones               14          Computer Vision
# 136         Emma Jones               11          Data Visualization
# 137         Frank Johnson            17          Software Testing
# 137         Frank Johnson            18          Blockchain Security
# 137         Frank Johnson            12          Web Development
# 137         Frank Johnson            14          Computer Vision
# 137         Frank Johnson            11          Data Visualization
# 138         Alice Johnson            1           Data Science Fundamentals
# 138         Alice Johnson            7           Software Engineering
# 138         Alice Johnson            4           Database Management
# 138         Alice Johnson            5           Programming in Python
# 139         Charlie Williams         12          Web Development
# 139         Charlie Williams         13          Ethical Hacking
# 139         Charlie Williams         8           Operating Systems
# 139         Charlie Williams         4           Database Management
# 140         Hannah Williams          15          Cloud Computing
# 140         Hannah Williams          1           Data Science Fundamentals
# 140         Hannah Williams          10          Cryptography
# 140         Hannah Williams          17          Software Testing
# 141         Grace Brown              6           Network Security
# 141         Grace Brown              8           Operating Systems
# 141         Grace Brown              17          Software Testing
# 141         Grace Brown              13          Ethical Hacking
# 142         Frank Brown              7           Software Engineering
# 142         Frank Brown              13          Ethical Hacking
# 142         Frank Brown              20          Advanced Algorithms
# 142         Frank Brown              5           Programming in Python
# 143         Grace Garcia             3           Cybersecurity Basics
# 143         Grace Garcia             18          Blockchain Security
# 143         Grace Garcia             10          Cryptography
# 143         Grace Garcia             13          Ethical Hacking
# 144         Charlie Brown            3           Cybersecurity Basics
# 144         Charlie Brown            9           AI & Deep Learning
# 144         Charlie Brown            12          Web Development
# 144         Charlie Brown            16          Data Mining
# 145         Frank Brown              6           Network Security
# 145         Frank Brown              5           Programming in Python
# 145         Frank Brown              20          Advanced Algorithms
# 145         Frank Brown              16          Data Mining
# 146         Emma Johnson             11          Data Visualization
# 146         Emma Johnson             16          Data Mining
# 146         Emma Johnson             12          Web Development
# 146         Emma Johnson             20          Advanced Algorithms
# 146         Emma Johnson             14          Computer Vision
# 147         David Johnson            16          Data Mining
# 147         David Johnson            15          Cloud Computing
# 147         David Johnson            9           AI & Deep Learning
# 147         David Johnson            6           Network Security
# 148         Hannah Jones             12          Web Development
# 148         Hannah Jones             15          Cloud Computing
# 148         Hannah Jones             14          Computer Vision
# 148         Hannah Jones             16          Data Mining
# 148         Hannah Jones             9           AI & Deep Learning
# 149         Emma Garcia              14          Computer Vision
# 149         Emma Garcia              19          Digital Forensics
# 149         Emma Garcia              1           Data Science Fundamentals
# 150         Hannah Williams          14          Computer Vision
# 150         Hannah Williams          11          Data Visualization
# 150         Hannah Williams          6           Network Security

# %% [markdown]
# # 5. Querying the Database
# - Retrieve All Students and Their Courses

# %%
def get_student_courses(student_id):
    query = """
    SELECT Students.Name, Courses.Course_Name 
    FROM Students
    JOIN Enrollment ON Students.Student_ID = Enrollment.Student_ID
    JOIN Courses ON Enrollment.Course_ID = Courses.Course_ID
    WHERE Students.Student_ID = ?
    """
    cursor.execute(query, (student_id,))
    return cursor.fetchall()

# Fetch courses for a random student
print(get_student_courses(student_ids[1]))
# Out:
# [('Bob Smith', 'Programming in Python'), ('Bob Smith', 'Data Visualization'), ('Bob Smith', 'Web Development'), ('Bob Smith', 'Cloud Computing')]

# %% [markdown]
# # Show Each Table in the Database

# %%
def show_tables():
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()
    print("\nDatabase Tables:")
    for table in tables:
        print(f"- {table[0]}")

show_tables()
# Out:
# Database Tables:
# - Department
# - sqlite_sequence
# - Students
# - Courses
# - Lecturers
# - Enrollment

# %% [markdown]
# # Display 10 Data from Each Table

# %%
def display_table_data(table_name):
    print(f"\nData from {table_name}:")
    cursor.execute(f"SELECT * FROM {table_name} LIMIT 10;")  # Limiting output for readability
    rows = cursor.fetchall()
    for row in rows:
        print(row)

# Display data for all tables
tables = ["Department", "Students", "Courses", "Lecturers", "Enrollment"]
for table in tables:
    display_table_data(table)
# Out:
# Data from Department:
# (1, 'Data Science')
# (2, 'Computer Science')
# (3, 'Cyber Security')
#
# Data from Students:
# (1, 'Charlie Smith', 1)
# (2, 'Bob Smith', 1)
# (3, 'Alice Smith', 1)
# (4, 'Alice Johnson', 1)
# (5, 'Charlie Johnson', 1)
# (6, 'Charlie Jones', 1)
# (7, 'Hannah Brown', 1)
# (8, 'Grace Jones', 1)
# (9, 'Hannah Brown', 1)
# (10, 'Charlie Williams', 1)
#
# Data from Courses:
# (1, 'Data Science Fundamentals', 3)
# (2, 'Machine Learning', 4)
# (3, 'Cybersecurity Basics', 3)
# (4, 'Database Management', 4)
# (5, 'Programming in Python', 3)
# (6, 'Network Security', 4)
# (7, 'Software Engineering', 3)
# (8, 'Operating Systems', 3)
# (9, 'AI & Deep Learning', 4)
# (10, 'Cryptography', 4)
#
# Data from Lecturers:
# (1, 'Grace Williams', 3)
# (2, 'Grace Garcia', 1)
# (3, 'Bob Brown', 2)
# (4, 'Frank Garcia', 2)
# (5, 'Charlie Williams', 2)
# (6, 'Bob Garcia', 1)
# (7, 'David Williams', 1)
# (8, 'Emma Johnson', 2)
# (9, 'Grace Johnson', 3)
# (10, 'Grace Smith', 2)
#
# Data from Enrollment:
# (1, 13)
# (1, 4)
# (1, 18)
# (1, 14)
# (1, 9)
# (2, 11)
# (2, 15)
# (2, 5)
# (2, 12)
# (3, 15)

# %% [markdown]
# # Calculate Time Complexity of Each Database Operation

# %%
import time

# Measure execution time for inserting a student
def measure_insert_student():
    start_time = time.time()
    cursor.execute("INSERT INTO Students (Name, Dept_ID) VALUES ('John Doe', 1)")
    conn.commit()
    end_time = time.time()
    print(f"Insert Student Execution Time: {end_time - start_time:.6f} seconds (O(1))")

# Measure execution time for selecting all students
def measure_select_students():
    start_time = time.time()
    cursor.execute("SELECT * FROM Students")
    cursor.fetchall()
    end_time = time.time()
    print(f"Select All Students Execution Time: {end_time - start_time:.6f} seconds (O(n))")

# Measure execution time for selecting a specific student
def measure_select_specific_student():
    start_time = time.time()
    cursor.execute("SELECT * FROM Students WHERE Student_ID = 1")
    cursor.fetchall()
    end_time = time.time()
    print(f"Select Specific Student Execution Time: {end_time - start_time:.6f} seconds (O(1))")

# Measure execution time for enrolling a student
def measure_enroll_student():
    start_time = time.time()
    cursor.execute("INSERT INTO Enrollment (Student_ID, Course_ID) VALUES (1, 3)")
    conn.commit()
    end_time = time.time()
    print(f"Enroll Student Execution Time: {end_time - start_time:.6f} seconds (O(1))")

# Measure execution time for retrieving student courses
def measure_get_student_courses():
    start_time = time.time()
    cursor.execute("""
        SELECT Students.Name, Courses.Course_Name 
        FROM Students
        JOIN Enrollment ON Students.Student_ID = Enrollment.Student_ID
        JOIN Courses ON Enrollment.Course_ID = Courses.Course_ID
        WHERE Students.Student_ID = 1
    """)
    cursor.fetchall()
    end_time = time.time()
    print(f"Retrieve Student Courses Execution Time: {end_time - start_time:.6f} seconds (O(n))")

# Run all time complexity measurements
print("\n### Time Complexity Analysis ###")
measure_insert_student()
measure_select_students()
measure_select_specific_student()
measure_enroll_student()
measure_get_student_courses()
# Out:
# ### Time Complexity Analysis ###
# Insert Student Execution Time: 0.003738 seconds (O(1))
# Select All Students Execution Time: 0.000000 seconds (O(n))
# Select Specific Student Execution Time: 0.000000 seconds (O(1))
# Enroll Student Execution Time: 0.003181 seconds (O(1))
# Retrieve Student Courses Execution Time: 0.000000 seconds (O(n))

# %%
# Close the connection
conn.close()
